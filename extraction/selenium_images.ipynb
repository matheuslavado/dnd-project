# %%
import time
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import pandas as pd
from tqdm.auto import tqdm
import multiprocess

# %%
data = pd.read_csv('../transform/monster_lb.csv')
data.head()
# Out:
#                        Nome       Tipo Tamanho     Tendência  PV_médio  \
# 0                 AARAKOCRA  Humanoide   Médio  neutro e bom        13
# 1  ABOCANHADOR MATRAQUEANTE  Aberração   Média        neutro        67
# 2                   ABOLETE  Aberração  Grande    leal e mau       135
# 3                      DEVA  Celestial   Médio    leal e bom       136
# 4                PLANETÁRIO  Celestial  Grande    leal e bom       200
#
#       PV_dados  CA  Deslocamento  Força  mod_força  ...  mod_inteligência  \
# 0          3d8  12           6.0   10.0        0.0  ...               0.0
# 1     9d8 + 27   9           3.0   10.0        0.0  ...              -4.0
# 2   18d10 + 36  17           3.0   21.0        5.0  ...               4.0
# 3    16d8 + 64  17           9.0   18.0        4.0  ...               3.0
# 4  16d10 + 112  19          12.0   24.0        7.0  ...               4.0
#
#    Sabedoria  mod_sabedoria  Carisma  mod_carisma  \
# ...

# %%
# Pegando nomes para procurar imagens no Google Imagens

nomes = list(data['Nome'])

# %%
links = []

# %%
# rodando Selenium para cada nome

for i in tqdm(range(len(nomes))):
    busca = nomes[i]
    print(i)
    print(nomes[i], '\n')
    
    
    driver = webdriver.Chrome()

    driver.set_page_load_timeout(10)
    
    driver.get('https://images.google.com/')
    
    driver.find_element_by_name('q').send_keys(f'{busca} D&D')
    
    driver.find_element_by_name('q').send_keys(Keys.ENTER)

    time.sleep(5)
    driver.find_element_by_xpath('//*[@id="islrg"]/div[1]/div[2]').click()
    time.sleep(5)
    x = driver.find_element_by_xpath('/html/body/div[2]/c-wiz/div[3]/div[2]/div[3]/div/div/div[3]/div[2]/c-wiz/div[1]/div[1]/div/div[2]/a/img')
    time.sleep(1)
    
    links.append((nomes[i], x.get_attribute('src')))
    
    time.sleep(1)

    driver.quit()
    
    time.sleep(5)
# Out:
# ...
# 0
# AARAKOCRA
#
# 1
# ABOCANHADOR MATRAQUEANTE
#
# 2
# ABOLETE
#
# 3
# DEVA
#
# 4
# PLANETÁRIO
#
# 5
# SOLAR
#
# 6
# ANKHEG
#
# 7
# ANOMALIA DA ÁGUA
#
# 8
# APARIÇÃO
#
# 9
# ARBUSTO ERRANTE
#
# 10
# AZER
#
# 11
# BANSHEE
#
# 12
# BASILISCO
#
# 13
# BEHIR
#
# 14
# BRUXA DA NOITE
#
# 15
# BRUXA DO MAR
#
# 16
# BRUXA VERDE
#
# 17
# BUGBEAR
#
# 18
# BUGBEAR COMANDANTE
#
# 19
# BULETTE
#
# 20
# BULLYWUG
#
# 21
# CAÇADOR INVISÍVEL
#
# 22
# CAMBION
#
# 23
# CÃO INFERNAL
#
# 24
# CARNIÇAL
#
# 25
# LÍVIDO
#
# 26
# CAVALEIRO DA MORTE
#
# 27
# CAVEIRA FLAMEJANTE
#
# 28
# CENTAURO
#
# 29
# CHUUL
#
# 30
# CICLOPE
#
# 31
# COCATRIZ
#
# 32
# COUATL
#
# 33
# DEMILICH
#
# 34
# BALOR
#
# 35
# BARLGURA
#
# 36
# CHASME
#
# 37
# DRETCH
#
# 38
# GITH GLABREZU
#
# 39
# GORISTRO
#
# 40
# HERZOU
#
# 41
# MANES
#
# 42
# MARILITH
#
# 43
# NALFESHNEE
#
# 44
# QUASIT
#
# 45
# DEMÔNIO DAS SOMBRAS
#
# 46
# VROCK
#
# 47
# YOCHLOL
#
# 48
# DEVORADOR DE INTELECTO
#
# 49
# DEVORADOR DE MENTES
#
# 50
# ...

# %%
len(links)
# Out:
# 437

# %%
links_array = np.array(links)

# %%
list(links_array[:,0])
# Out:
# ['AARAKOCRA',
#  'ABOCANHADOR MATRAQUEANTE',
#  'ABOLETE',
#  'AARAKOCRA',
#  'ABOCANHADOR MATRAQUEANTE',
#  'ABOLETE',
#  'DEVA',
#  'PLANETÁRIO',
#  'SOLAR',
#  'ANKHEG',
#  'ANOMALIA DA ÁGUA',
#  'APARIÇÃO',
#  'ARBUSTO ERRANTE',
#  'AZER',
#  'BANSHEE',
#  'BASILISCO',
#  'BEHIR',
#  'BRUXA DA NOITE',
#  'BRUXA DO MAR',
#  'BRUXA VERDE',
#  'BUGBEAR',
#  'BUGBEAR COMANDANTE',
#  'BULETTE',
#  'BULLYWUG',
#  'CAÇADOR INVISÍVEL',
#  'CAMBION',
#  'CÃO INFERNAL',
#  'CARNIÇAL',
#  'LÍVIDO',
#  'CAVALEIRO DA MORTE',
#  'CAVEIRA FLAMEJANTE',
#  'CENTAURO',
#  'CHUUL',
#  'CICLOPE',
#  'COCATRIZ',
#  'COUATL',
#  'DEMILICH',
#  'BALOR',
#  'BARLGURA',
#  'CHASME',
#  'DRETCH',
#  'GITH GLABREZU',
#  'GORISTRO',
#  'HERZOU',
#  'MANES',
#  'MARILITH',
#  'NALFESHNEE',
#  'QUASIT',
#  'DEMÔNIO DAS SOMBRAS',
#  'VROCK',
#  'YOCHLOL',
#  'DEVORADOR DE INTELECTO',
#  'DEVORADOR DE MENTES',
#  'DEVORADOR DE MENTES  ARCANISTA',
#  'DIABO BARBADO',
#  'DIABO FARPADO',
#  'DIABO DOS OSSOS',
# ...

# %%
links_df = pd.DataFrame({'Nome':links_array[:,0], 'links':links_array[:,1]}).

# %%
# salvando links csv
links_df.drop_duplicates().to_csv('links.csv', index = False)

# %%
# criando cópia e arrumando alguns links manualmente

# %%
links_df2 = links_df.drop_duplicates().reset_index(drop = True).copy()
links_df2
# Out:
#                          Nome  \
# 0                   AARAKOCRA
# 1    ABOCANHADOR MATRAQUEANTE
# 2                     ABOLETE
# 3                        DEVA
# 4                  PLANETÁRIO
# ..                        ...
# 429                     NOBRE
# 430                    PLEBEU
# 431                    RUFIÃO
# 432                 SACERDOTE
# 433                  VETERANO
#
#                                                  links
# 0    https://i.pinimg.com/originals/8c/7a/f0/8c7af0...
# 1    https://pm1.narvii.com/6701/b36fff01b7ebc07764...
# 2    https://pm1.narvii.com/6701/f795bc2d3e8b320810...
# 3    https://i.pinimg.com/originals/46/09/f1/4609f1...
# 4    https://pm1.narvii.com/6704/70c352f8ffe70b0915...
# ..                                                 ...
# 429  https://i.pinimg.com/originals/1e/01/13/1e0113...
# 430  https://vignette.wikia.nocookie.net/tsrd/image...
# 431  https://biroscanerd.files.wordpress.com/2012/0...
# ...

# %%
links_df2.iloc[55,1] = 'https://i.pinimg.com/originals/1d/3c/c5/1d3cc56ffcdd38d3d55c6a2ff1ea18e7.png'
links_df2.iloc[67,1] = 'https://www.aidedd.org/dnd/images/triceratops.jpg'
links_df2.iloc[283,1] = 'https://66.media.tumblr.com/edee3c44a1278f81fd2434dcd89c5cb1/47974d07a6dfe731-f7/s540x810/9feaf22e32d96e626fab7d28f88ac7efa4b4db7f.jpg'
links_df2.iloc[328,1] = 'https://i.pinimg.com/originals/ec/89/ce/ec89ce2257fbabd883156547a50b5542.jpg'
links_df2.iloc[329,1] = 'https://i.pinimg.com/originals/ec/89/ce/ec89ce2257fbabd883156547a50b5542.jpg'
links_df2.iloc[346,1] = 'https://i.pinimg.com/originals/12/42/86/124286e13ea31a32730f08190bf0881a.jpg'
links_df2.iloc[360,1] = 'https://images-na.ssl-images-amazon.com/images/I/51zi156vtAL._AC_.jpg'
links_df2.iloc[361,1] = 'https://images-na.ssl-images-amazon.com/images/I/51zi156vtAL._AC_.jpg'
links_df2.iloc[368,1] = 'https://images-na.ssl-images-amazon.com/images/I/51zi156vtAL._AC_.jpg'
links_df2.iloc[374,1] = 'https://images-na.ssl-images-amazon.com/images/I/51zi156vtAL._AC_.jpg'
links_df2.iloc[377,1] = 'https://images-na.ssl-images-amazon.com/images/I/51zi156vtAL._AC_.jpg'
links_df2.iloc[390,1] = 'https://images-na.ssl-images-amazon.com/images/I/51zi156vtAL._AC_.jpg'
links_df2.iloc[406,1] = 'https://images-na.ssl-images-amazon.com/images/I/51zi156vtAL._AC_.jpg'
links_df2.iloc[411,1] = 'https://images-na.ssl-images-amazon.com/images/I/51zi156vtAL._AC_.jpg'
links_df2.iloc[431,1] = 'https://images-na.ssl-images-amazon.com/images/I/51zi156vtAL._AC_.jpg'

# %%
links_df2.to_csv('links2.csv', index = False)
